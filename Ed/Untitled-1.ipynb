# %%
import os
for root, dirs, files in os.walk("."):
    for f in files:
        if f.endswith(".pth"):
            print(os.path.join(root, f))
# Out:
# .\Arthur\Arthur\SavedSeeds\nav_nav_v7_seed42.pth
# .\Arthur\Ed_Segway_Data\SavedSeeds\seed42\nav_ed_goal10_seed42.pth
# .\Arthur\Ed_Segway_Data\SavedSeeds\seed42\nav_ed_goal15_seed42.pth
# .\Arthur\Ozzy_Segway_Data\SavedSeeds\nav_cmp_seed42.pth
# .\Arthur\Ozzy_Segway_Data\SavedSeeds\nav_sac_cmp_seed42.pth
# .\Arthur\Ozzy_Segway_Data\SavedSeeds\nav_sac_nav_sac_v1_seed42.pth
# .\Arthur\SavedSeeds\nav_nav_v7_11_seed42.pth
# .\Ed\SAC_Saves\sac_segway_v1.pth
# .\Ed\SAC_Saves\sac_segway_v1_final.pth
# .\Ed\SavedSeeds\nav_ppo_cmp_seed42.pth
# .\Ed\SavedSeeds\nav_sac_cmp_seed42.pth
